# %%
# Write a pogram to creating class student, create 2 class attributes and 3 object attribute and display the information of students.

class student:
    college = 'Nutan'  # 2 class attributes
    city = 'Pune'
    
    def __init__(self,name,school,age):   # 3 object attribute
        self.name = name
        self.school = school
        self.age = age

s1 = student("Shardul", "VBHS", 11)

print("College:", s1.college)
print("City:", s1.city)
print("Name:", s1.name)
print("School:", s1.school)
print("Age:", s1.age)
# Out:
# College: Nutan
# City: Pune
# Name: Shardul
# School: VBHS
# Age: 11

# %%
# Write a pogram to creating class student, create 2 class attributes and 3 object attribute and display the information of students.

class student:
    college = 'Nutan'  # 2 class attributes
    city = 'Pune'
    
    def __init__(self,name,school,age):   # 3 object attribute
        self.name = name
        self.school = school
        self.age = age

    def info(self):
        print("College:", self.college)
        print("City:", self.city)
        print("Name:", self.name)
        print("School:", s1.school)
        print("Age:", self.age)

s1 = student('Shardul','VBHS',88)
s1.info()

s2 = student('Ram','RMC',22)
s2.info()
# Out:
# College: Nutan
# City: Pune
# Name: Shardul
# School: VBHS
# Age: 88
# College: Nutan
# City: Pune
# Name: Ram
# School: VBHS
# Age: 22

# %%
# inheritence
# polimorphism
# super keyword,decorater,
